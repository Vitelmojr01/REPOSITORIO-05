# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

print('Iniciando análise dos arquivos do SINASC...')

# lista dos meses pedidos na tarefa
meses = ['MAR', 'ABR', 'MAI', 'JUN', 'DEZ']

# cria a pasta onde os gráficos serão salvos
os.makedirs('graficos_sinasc', exist_ok=True)
print('Pasta "graficos_sinasc" pronta.')

for mes in meses:
    print(f'\nLendo a base do mês: {mes}')
    
    caminho_arquivo = f'SINASC_RO_2019_{mes}.csv'
    sinasc = pd.read_csv(caminho_arquivo)
    
    print(f'Base {mes} carregada com sucesso.')
    print(f'Quantidade de linhas: {sinasc.shape[0]}')
    print(f'Quantidade de colunas: {sinasc.shape[1]}')

    # gráfico 1 - idade da mãe
    plt.figure(figsize=(8,5))
    sns.histplot(sinasc['IDADEMAE'].dropna(), bins=20)
    plt.title(f'Idade da mãe - {mes}/2019')
    plt.xlabel('Idade da mãe')
    plt.ylabel('Frequência')
    plt.savefig(f'graficos_sinasc/idade_mae_{mes}.png')
    plt.show()
    print(f'Gráfico de idade da mãe do mês {mes} salvo com sucesso.')

    # gráfico 2 - escolaridade da mãe
    plt.figure(figsize=(8,5))
    sinasc['ESCMAE'].value_counts().sort_index().plot.bar()
    plt.title(f'Escolaridade da mãe - {mes}/2019')
    plt.xlabel('Escolaridade')
    plt.ylabel('Quantidade')
    plt.savefig(f'graficos_sinasc/escolaridade_mae_{mes}.png')
    plt.show()
    print(f'Gráfico de escolaridade da mãe do mês {mes} salvo com sucesso.')

    # gráfico 3 - consultas pré-natal
    plt.figure(figsize=(8,5))
    sinasc['CONSULTAS'].value_counts().sort_index().plot.bar()
    plt.title(f'Consultas pré-natal - {mes}/2019')
    plt.xlabel('Número de consultas')
    plt.ylabel('Quantidade')
    plt.savefig(f'graficos_sinasc/consultas_{mes}.png')
    plt.show()
    print(f'Gráfico de consultas do mês {mes} salvo com sucesso.')

print('\nTodos os gráficos foram gerados com sucesso.')
# Out:
# Iniciando análise dos arquivos do SINASC...
# Pasta "graficos_sinasc" pronta.
#
# Lendo a base do mês: MAR
# Base MAR carregada com sucesso.
# Quantidade de linhas: 6844
# Quantidade de colunas: 11
# Gráfico de idade da mãe do mês MAR salvo com sucesso.
# Gráfico de escolaridade da mãe do mês MAR salvo com sucesso.
# Gráfico de consultas do mês MAR salvo com sucesso.
#
# Lendo a base do mês: ABR
# Base ABR carregada com sucesso.
# Quantidade de linhas: 9217
# Quantidade de colunas: 11
# Gráfico de idade da mãe do mês ABR salvo com sucesso.
# Gráfico de escolaridade da mãe do mês ABR salvo com sucesso.
# Gráfico de consultas do mês ABR salvo com sucesso.
#
# Lendo a base do mês: MAI
# Base MAI carregada com sucesso.
# Quantidade de linhas: 11582
# Quantidade de colunas: 11
# Gráfico de idade da mãe do mês MAI salvo com sucesso.
# Gráfico de escolaridade da mãe do mês MAI salvo com sucesso.
# Gráfico de consultas do mês MAI salvo com sucesso.
#
# Lendo a base do mês: JUN
# Base JUN carregada com sucesso.
# Quantidade de linhas: 13758
# Quantidade de colunas: 11
# Gráfico de idade da mãe do mês JUN salvo com sucesso.
# Gráfico de escolaridade da mãe do mês JUN salvo com sucesso.
# Gráfico de consultas do mês JUN salvo com sucesso.
#
# Lendo a base do mês: DEZ
# Base DEZ carregada com sucesso.
# Quantidade de linhas: 27028
# Quantidade de colunas: 11
# Gráfico de idade da mãe do mês DEZ salvo com sucesso.
# Gráfico de escolaridade da mãe do mês DEZ salvo com sucesso.
# Gráfico de consultas do mês DEZ salvo com sucesso.
#
# Todos os gráficos foram gerados com sucesso.

# %% [markdown]
# EXPLICAÇÃO:O script automatiza a geração dos gráficos usando uma lista de meses e um loop for. Em vez de carregar cada arquivo manualmente, o código percorre automaticamente os meses MAR, ABR, MAI, JUN e DEZ, lendo cada base e gerando três gráficos para cada uma (idade da mãe, escolaridade e consultas pré-natal).
#
# A automatização acontece porque:
#
# a lista meses define os arquivos a serem processados;
# o for executa o mesmo processo para cada mês;
# os gráficos são salvos automaticamente na pasta graficos_sinasc.
#
# Isso permite que novos meses sejam adicionados facilmente apenas incluindo o nome na lista, sem precisar alterar o restante do código.
#
# 2. print dos arquivos gerados na pasta
#
# O print mostra que foram gerados corretamente os gráficos para todos os meses solicitados:
#
# consultas: ABR, DEZ, JUN, MAI, MAR
# escolaridade: ABR, DEZ, JUN, MAI, MAR
# idade da mãe: ABR, DEZ, JUN, MAI, MAR
#
# Total: 15 gráficos (3 por mês), confirmando que o script executou corretamente.
